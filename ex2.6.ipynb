# %% [markdown]
# ### 例 2.6
# ### 用 LLE 对“瑞士卷”数据集进行降维。下面是基于 sklearn 实现的 LLE 示例, 数据集生成和 LLE 降维的核心代码如下:

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import manifold, datasets

# %%
#X, color = datasets.samples_generator.make_swiss_roll(n_samples=1500)
X, color = datasets.make_swiss_roll(n_samples=1500)
print("Computing LLE embedding")
# Out:
# Computing LLE embedding

# %%
X_r, err = manifold.locally_linear_embedding(X, n_neighbors=10, n_components=2)
print("Done. Reconstruction error: %g" % err)
# Out:
# Done. Reconstruction error: 4.27965e-09

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
fig = plt.figure()

ax = fig.add_subplot(211, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)

ax.set_title("原始数据")
ax = fig.add_subplot(212)
ax.scatter(X_r[:, 0], X_r[:, 1], c=color, cmap=plt.cm.Spectral)
plt.axis('tight')
plt.xticks([]), plt.yticks([])
plt.xlabel('LL1')
plt.ylabel('LL2')
plt.title('投射后数据')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.manifold import LocallyLinearEmbedding

# 生成 Swiss Roll 数据集
X, color = datasets.make_swiss_roll(n_samples=1500)

print("Computing LLE embedding")
# 创建 LLE 模型实例
lle = LocallyLinearEmbedding(n_neighbors=10, n_components=2)

# 应用 LLE 进行降维
X_lle = lle.fit_transform(X)
print("Done. Reconstruction error: %g" % lle.reconstruction_error_)

# 可视化结果
fig = plt.figure(figsize=(8, 6))

# 原始数据的3D散点图
ax = fig.add_subplot(211, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
ax.set_title("Original data")

# LLE降维后的2D散点图
ax = fig.add_subplot(212)
ax.scatter(X_lle[:, 0], X_lle[:, 1], c=color, cmap=plt.cm.Spectral)
plt.axis('tight')
plt.xticks([])  
plt.yticks([])  
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('LLE embedding')
plt.show()
# Out:
# Computing LLE embedding
# Done. Reconstruction error: 4.2732e-08

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.manifold import LocallyLinearEmbedding

# 生成 Swiss Roll 数据集
X, color = datasets.make_swiss_roll(n_samples=1500)

print("Computing LLE embedding")

# 应用 LLE 进行降维
lle = LocallyLinearEmbedding(n_neighbors=10, n_components=2)
X_lle = lle.fit_transform(X)

# 可视化结果
plt.figure(figsize=(12, 6))  # 调整整体布局大小

# 原始数据的3D散点图
ax = plt.subplot(121, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
ax.set_title("Original data")

# LLE降维后的2D散点图
ax = plt.subplot(122)
ax.scatter(X_lle[:, 0], X_lle[:, 1], c=color, cmap=plt.cm.Spectral)
ax.set_title("LLE embedding")
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')

#plt.tight_layout()
plt.show()
# Out:
# Computing LLE embedding

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.manifold import LocallyLinearEmbedding

# 生成 Swiss Roll 数据集
X, color = datasets.make_swiss_roll(n_samples=1500)

print("Computing LLE embedding")
lle = LocallyLinearEmbedding(n_neighbors=10, n_components=2)
X_lle = lle.fit_transform(X)
print("Done. Reconstruction error: %g" % lle.reconstruction_error_)

# 可视化结果
fig = plt.figure()

# 原始数据的 3D 散点图
ax = fig.add_subplot(211, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
ax.set_title("Original data")

# LLE 降维后的 2D 散点图
ax = fig.add_subplot(212)
ax.scatter(X_lle[:, 0], X_lle[:, 1], c=color, cmap=plt.cm.Spectral)
plt.axis('tight')
plt.xticks([])  
plt.yticks([])  
plt.xlabel('LL1')
plt.ylabel('LL2')
plt.title('Projected data')

plt.show()
# Out:
# Computing LLE embedding
# Done. Reconstruction error: 3.59093e-08
